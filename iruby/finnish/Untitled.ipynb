# %%
require 'btp'
# Out:
# Install the spreadsheet gem version ~>1.1.1 for using spreadsheet functions.
#
# Install the mechanize gem version ~>2.7.5 for using mechanize functions.
# true

# %%
bigram_df = BTP::Bigram.new('../../spec/fixtures/finnish/finnish-task1-train').parse
# Out:
# aalloittaisuus
# aalloppi
# aaltomuoto
# aaltopelti
# aaltopelti
# aaltopituus
# aalto
# aaltosulkumerkki
# aamiaishetki
# aamuhetki
# aamukahvi
# aamukahvi
# aamukahvi
# aamuntorkku
# aamupuku
# aamupuku
# aamurusko
# aamutorkku
# aamutossu
# äänennopeus
# äänestyskoppi
# äänettömyys
# äänettömyys
# äänilevystö
# äänilevystö
# äänilevystö
# äänioikeus
# äänivalli
# ääntö
# aaprotti
# äärellisyys
# äärivasemmisto
# äärivasemmisto
# aarni
# aarrelöytö
# aasianjokipääsky
# aasiankilpikierto
# aasiankiuru
# aasianmarmorimurri
# aasiansieppokerttu
# aasiansieppokerttu
# aasiantörmäpääsky
# aasianuuttukyyhky
# aasianvuoripeippo
# aasinmaksaruoho
# aasinmaksaruoho
# aasinmaksaruoho
# aasi
# aataminpuku
# aatelisarvo
# aatelisarvo
# aatelisneito
# aatelisneito
# aatelissuku
# aaterikkaus
# aaterikkaus
# aateveli
# aateveli
# aateveli
# aatto
# aavesärky
# aavikkogundi
# aavikkokerttu
# aavikkotylli
# aavikkounikeko
# aavikkounikeko
# aavistuslähtö
# abaloni
# abatasepti
# abatsi
# ...
