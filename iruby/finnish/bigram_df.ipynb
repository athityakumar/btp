# %%
require 'btp'
# Out:
# Install the spreadsheet gem version ~>1.1.1 for using spreadsheet functions.
#
# Install the mechanize gem version ~>2.7.5 for using mechanize functions.
# true

# %%
bigram_df = BTP::Bigram.new('../../spec/fixtures/finnish/finnish-task1-train').parse
# Out:
# aalloittaisuus
# aalloppi
# aaltomuoto
# aaltopelti
# aaltopelti
# aaltopituus
# aalto
# aaltosulkumerkki
# aamiaishetki
# aamuhetki
# aamukahvi
# aamukahvi
# aamukahvi
# aamuntorkku
# aamupuku
# aamupuku
# aamurusko
# aamutorkku
# aamutossu
# äänennopeus
# äänestyskoppi
# äänettömyys
# äänettömyys
# äänilevystö
# äänilevystö
# äänilevystö
# äänioikeus
# äänivalli
# ääntö
# aaprotti
# äärellisyys
# äärivasemmisto
# äärivasemmisto
# aarni
# aarrelöytö
# aasianjokipääsky
# aasiankilpikierto
# aasiankiuru
# aasianmarmorimurri
# aasiansieppokerttu
# aasiansieppokerttu
# aasiantörmäpääsky
# aasianuuttukyyhky
# aasianvuoripeippo
# aasinmaksaruoho
# aasinmaksaruoho
# aasinmaksaruoho
# aasi
# aataminpuku
# aatelisarvo
# aatelisarvo
# aatelisneito
# aatelisneito
# aatelissuku
# aaterikkaus
# aaterikkaus
# aateveli
# aateveli
# aateveli
# aatto
# aavesärky
# aavikkogundi
# aavikkokerttu
# aavikkotylli
# aavikkounikeko
# aavikkounikeko
# aavistuslähtö
# abaloni
# abatasepti
# abatsi
# ...

# %%
bigram_df.sort([:count], ascending: false)
# Out:
# #<Daru::DataFrame(276422x7)>
#             character_     left_1    right_1 character_     left_2    right_2      count
#         386          t          8         -2          i          9         -1        220
#         387          i          9         -1          t          8         -2        220
#        6832          i          6         -4          i          9         -1        215
#        6833          i          9         -1          i          6         -4        215
#        7294          t          9         -2          i         10         -1        204
#        7295          i         10         -1          t          9         -2        204
#        7290          i          7         -4          i         10         -1        166
#        7291          i         10         -1          i          7         -4        166
#        8012          i          5         -4          i          8         -1        154
# ...
